# %%
import pandas as pd

# %%
df = pd.read_csv('nba_games.csv', index_col=0)

# %%
df
# Out:
#          mp   mp.1    fg   fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0     240.0  240.0  30.0  73.0  0.411   8.0  25.0  0.320  22.0  29.0  ...
# 1     240.0  240.0  38.0  85.0  0.447   8.0  23.0  0.348  18.0  24.0  ...
# 2     240.0  240.0  42.0  75.0  0.560  11.0  29.0  0.379  16.0  19.0  ...
# 3     240.0  240.0  44.0  85.0  0.518  12.0  35.0  0.343  17.0  23.0  ...
# 4     240.0  240.0  41.0  93.0  0.441  13.0  36.0  0.361  21.0  28.0  ...
# ...     ...    ...   ...   ...    ...   ...   ...    ...   ...   ...  ...
# 7865  240.0  240.0  44.0  85.0  0.518  16.0  30.0  0.533  13.0  19.0  ...
# 7866  240.0  240.0  46.0  76.0  0.605  13.0  28.0  0.464  22.0  27.0  ...
# 7867  240.0  240.0  40.0  89.0  0.449  20.0  42.0  0.476  16.0  22.0  ...
# 7868  240.0  240.0  37.0  93.0  0.398  17.0  52.0  0.327   0.0   0.0  ...
# 7869  240.0  240.0  43.0  81.0  0.531  17.0  36.0  0.472   1.0   2.0  ...
#
#       tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0             25.0          35.1         200.0         106.0       TOR
# 1             50.0          38.3         200.0         121.0       WAS
# 2             29.1          34.0         235.0         118.0       DEN
# 3             37.5          36.3         155.0         126.0       DET
# 4             50.0          27.0         154.0         120.0       MIA
# ...            ...           ...           ...           ...       ...
# 7865          19.2          30.2         300.0         130.0       POR
# 7866          24.1          40.9         179.0         142.0       POR
# 7867          29.6          29.8         199.0         130.0       PHO
# 7868          46.7          33.5         186.0         114.0       MIL
# 7869          20.8          30.9         249.0         127.0       BOS
#
#       total_opp  home_opp  season        date    won
# 0           102         1    2022  2021-12-05  False
# 1            90         0    2022  2021-12-05   True
# 2           117         1    2022  2022-01-23  False
# 3           111         0    2022  2022-01-23   True
# 4           108         1    2023  2022-10-19   True
# ...         ...       ...     ...         ...    ...
# 7865        109         0    2022  2021-11-09   True
# 7866        116         1    2024  2024-01-14   True
# 7867        127         0    2024  2024-01-14  False
# 7868        104         1    2024  2024-04-09  False
# 7869         91         0    2024  2024-04-09   True
#
# [7870 rows x 150 columns]

# %%
df = df.sort_values("date")

# %%
df = df.reset_index(drop=True)

# %%
#remove redundant columns
del df["mp.1"]
del df["mp_opp.1"]
del df["index_opp"]

# %%
#split dataframe by teams, target = next game
def add_target(group):
    group["target"] = group["won"].shift(-1)
    return group

df = df.groupby("team", group_keys=False).apply(add_target)
# Out:
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   group["target"] = group["won"].shift(-1)
# /tmp/ipykernel_1223/2537704205.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("team", group_keys=False).apply(add_target)

# %%
df[df["team"] == "DEN"]
# Out:
#          mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 8     240.0  44.0  83.0  0.530  17.0  39.0  0.436   5.0   9.0  0.556  ...
# 45    240.0  44.0  86.0  0.512   9.0  30.0  0.300   5.0   8.0  0.625  ...
# 89    240.0  35.0  86.0  0.407   9.0  38.0  0.237   8.0  12.0  0.667  ...
# 98    240.0  42.0  83.0  0.506  10.0  28.0  0.357  16.0  24.0  0.667  ...
# 145   240.0  43.0  83.0  0.518  11.0  36.0  0.306   9.0  13.0  0.692  ...
# ...     ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 7811  240.0  39.0  87.0  0.448   9.0  30.0  0.300  21.0  25.0  0.840  ...
# 7821  240.0  42.0  89.0  0.472  16.0  38.0  0.421   8.0   9.0  0.889  ...
# 7844  240.0  35.0  75.0  0.467  13.0  31.0  0.419  16.0  20.0  0.800  ...
# 7848  240.0  29.0  83.0  0.349   9.0  30.0  0.300  13.0  18.0  0.722  ...
# 7865  240.0  43.0  80.0  0.538  14.0  29.0  0.483  17.0  20.0  0.850  ...
#
#       usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  home_opp  \
# 8             42.1         203.0         118.0       PHO         98         1
# 45            35.8         129.0         109.0       SAS         96         0
# 89            56.1         175.0         100.0       CLE         99         0
# 98            33.2         198.0         115.0       UTA        122         1
# 145           38.5         200.0         112.0       DAL         75         0
# ...            ...           ...           ...       ...        ...       ...
# 7811          33.3         142.0         113.0       LAL        119         1
# 7821          26.3         137.0         125.0       LAL        106         0
# 7844          36.6         137.0         114.0       MIN        106         0
# 7848          30.3         300.0         108.0       MIN        106         0
# 7865          41.4         230.0         138.0       MIN         90         1
#
#       season        date    won  target
# 8       2022  2021-10-20   True    True
# 45      2022  2021-10-22   True   False
# 89      2022  2021-10-25  False   False
# 98      2022  2021-10-26  False    True
# 145     2022  2021-10-29   True    True
# ...      ...         ...    ...     ...
# 7811    2024  2024-04-27  False    True
# 7821    2024  2024-04-29   True   False
# 7844    2024  2024-05-04  False   False
# 7848    2024  2024-05-06  False    True
# 7865    2024  2024-05-10   True     NaN
#
# [279 rows x 148 columns]

# %%
#switch data type in target column: true to 1, false to 0, null to 2
df["target"][pd.isnull(df["target"])] = 2
df["target"] = df["target"].astype(int, errors="ignore")
# Out:
# /tmp/ipykernel_1223/1015416111.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["target"][pd.isnull(df["target"])] = 2
# /tmp/ipykernel_1223/1015416111.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["target"][pd.isnull(df["target"])] = 2

# %%
df["won"].value_counts()
# Out:
# won
# True     3935
# False    3935
# Name: count, dtype: int64

# %%
df["target"].value_counts()
# Out:
# target
# 1    3920
# 0    3920
# 2      30
# Name: count, dtype: int64

# %%
nulls = pd.isnull(df).sum()

# %%
#get null columns
nulls = nulls[nulls > 0]

# %%
#get columns with no null
valid_columns = df.columns[~df.columns.isin(nulls.index)]

# %%
valid_columns
# Out:
# Index(['mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta', 'orb',
#        ...
#        'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp', 'team_opp', 'total_opp',
#        'home_opp', 'season', 'date', 'won', 'target'],
#       dtype='object', length=136)

# %%
df = df[valid_columns].copy()

# %%
df
# Out:
#          mp    fg    fga    fg%    3p   3pa    3p%    ft   fta   orb  ...  \
# 0     240.0  41.0   93.0  0.441  14.0  39.0  0.359  25.0  30.0   9.0  ...
# 1     240.0  45.0   95.0  0.474  15.0  42.0  0.357   9.0  19.0   5.0  ...
# 2     240.0  37.0   84.0  0.440  17.0  32.0  0.531  13.0  23.0   5.0  ...
# 3     240.0  48.0  105.0  0.457  17.0  45.0  0.378  14.0  18.0  13.0  ...
# 4     240.0  36.0   87.0  0.414  14.0  37.0  0.378  12.0  17.0  11.0  ...
# ...     ...   ...    ...    ...   ...   ...    ...   ...   ...   ...  ...
# 7865  240.0  43.0   80.0  0.538  14.0  29.0  0.483  17.0  20.0   8.0  ...
# 7866  240.0  36.0   84.0  0.429  12.0  36.0  0.333   9.0  10.0   7.0  ...
# 7867  240.0  38.0   81.0  0.469  10.0  30.0  0.333  15.0  19.0   6.0  ...
# 7868  240.0  39.0   91.0  0.429  11.0  33.0  0.333  16.0  25.0  15.0  ...
# 7869  240.0  41.0   80.0  0.513  13.0  34.0  0.382  11.0  14.0   9.0  ...
#
#       usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  home_opp  \
# 0             32.2         209.0         115.0       LAL        114         1
# 1            100.0         174.0         108.0       GSW        121         0
# 2             63.2         175.0         113.0       MIL        127         1
# 3             46.8         178.0         133.0       BRK        104         0
# 4             33.2         158.0         109.0       DEN        110         0
# ...            ...           ...           ...       ...        ...       ...
# 7865          41.4         230.0         138.0       MIN         90         1
# 7866          40.0         200.0         114.0       BOS        106         0
# 7867          26.8         220.0         110.0       DAL        105         1
# 7868          36.2         149.0         120.0       OKC        101         0
# 7869          26.8         233.0         128.0       CLE         93         1
#
#       season        date    won  target
# 0       2022  2021-10-19   True       1
# 1       2022  2021-10-19  False       0
# 2       2022  2021-10-19  False       1
# 3       2022  2021-10-19   True       0
# 4       2022  2021-10-20  False       1
# ...      ...         ...    ...     ...
# 7865    2024  2024-05-10   True       2
# 7866    2024  2024-05-11  False       2
# 7867    2024  2024-05-11  False       2
# 7868    2024  2024-05-11   True       2
# 7869    2024  2024-05-11   True       2
#
# [7870 rows x 136 columns]

# %%
#select best features for the model
from sklearn.linear_model import RidgeClassifier
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.model_selection import TimeSeriesSplit

rr = RidgeClassifier(alpha=1)

split = TimeSeriesSplit(n_splits=3)

sfs = SequentialFeatureSelector(rr, 
                                n_features_to_select=30, 
                                direction="forward",
                                cv=split,
                                n_jobs=1
                               )

# %%
#get columns to scale
removed_columns = ["season", "date", "won", "target", "team", "team_opp"]
selected_columns = df.columns[~df.columns.isin(removed_columns)]

# %%
from sklearn.preprocessing import MinMaxScaler

#scale
scaler = MinMaxScaler()
df[selected_columns] = scaler.fit_transform(df[selected_columns])

# %%
df
# Out:
#        mp        fg       fga       fg%    3p       3pa       3p%        ft  \
# 0     0.0  0.428571  0.508772  0.400000  0.48  0.529412  0.503472  0.568182
# 1     0.0  0.523810  0.543860  0.480488  0.52  0.588235  0.500000  0.204545
# 2     0.0  0.333333  0.350877  0.397561  0.60  0.392157  0.802083  0.295455
# 3     0.0  0.595238  0.719298  0.439024  0.60  0.647059  0.536458  0.318182
# 4     0.0  0.309524  0.403509  0.334146  0.48  0.490196  0.536458  0.272727
# ...   ...       ...       ...       ...   ...       ...       ...       ...
# 7865  0.0  0.476190  0.280702  0.636585  0.48  0.333333  0.718750  0.386364
# 7866  0.0  0.309524  0.350877  0.370732  0.40  0.470588  0.458333  0.204545
# 7867  0.0  0.357143  0.298246  0.468293  0.32  0.352941  0.458333  0.340909
# 7868  0.0  0.380952  0.473684  0.370732  0.36  0.411765  0.458333  0.363636
# 7869  0.0  0.428571  0.280702  0.575610  0.44  0.431373  0.543403  0.250000
#
#            fta       orb  ...  usg%_max_opp  ortg_max_opp  drtg_max_opp  \
# 0     0.576923  0.310345  ...      0.130769      0.540404      0.367089
# 1     0.365385  0.172414  ...      1.000000      0.363636      0.278481
# 2     0.442308  0.172414  ...      0.528205      0.368687      0.341772
# 3     0.346154  0.448276  ...      0.317949      0.383838      0.594937
# 4     0.326923  0.379310  ...      0.143590      0.282828      0.291139
# ...        ...       ...  ...           ...           ...           ...
# 7865  0.384615  0.275862  ...      0.248718      0.646465      0.658228
# 7866  0.192308  0.241379  ...      0.230769      0.494949      0.354430
# 7867  0.365385  0.206897  ...      0.061538      0.595960      0.303797
# 7868  0.480769  0.517241  ...      0.182051      0.237374      0.430380
# 7869  0.269231  0.310345  ...      0.061538      0.661616      0.531646
#
#       team_opp  total_opp  home_opp  season        date    won  target
# 0          LAL   0.398058       1.0    2022  2021-10-19   True       1
# 1          GSW   0.466019       0.0    2022  2021-10-19  False       0
# 2          MIL   0.524272       1.0    2022  2021-10-19  False       1
# 3          BRK   0.300971       0.0    2022  2021-10-19   True       0
# 4          DEN   0.359223       0.0    2022  2021-10-20  False       1
# ...        ...        ...       ...     ...         ...    ...     ...
# 7865       MIN   0.165049       1.0    2024  2024-05-10   True       2
# 7866       BOS   0.320388       0.0    2024  2024-05-11  False       2
# 7867       DAL   0.310680       1.0    2024  2024-05-11  False       2
# 7868       OKC   0.271845       0.0    2024  2024-05-11   True       2
# 7869       CLE   0.194175       1.0    2024  2024-05-11   True       2
#
# [7870 rows x 136 columns]

# %%
sfs.fit(df[selected_columns], df["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30, n_jobs=1)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['fg',
#  'fga',
#  'fg%',
#  '3p%',
#  'drb',
#  'pf',
#  'pts',
#  'efg%',
#  'usg%',
#  'ortg',
#  'fga_max',
#  '3p_max',
#  'orb_max',
#  'pts_max',
#  'orb%_max',
#  'trb%_max',
#  'usg%_max',
#  'total',
#  'ft_opp',
#  'trb_opp',
#  'pf_opp',
#  'usg%_opp',
#  'drtg_opp',
#  'orb_max_opp',
#  'trb_max_opp',
#  'pf_max_opp',
#  'ftr_max_opp',
#  'orb%_max_opp',
#  'trb%_max_opp',
#  'drtg_max_opp']

# %%
#model
def backtest(data, model, predictors, start=2, step=1):
    all_predictions = []
    
    seasons = sorted(data["season"].unique())
    
    for i in range(start, len(seasons), step):
        season = seasons[i]
        train = data[data["season"] < season]
        test = data[data["season"] == season]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(df, rr, predictors)

# %%
predictions
# Out:
#       actual  prediction
# 5286       1           1
# 5287       0           1
# 5288       1           0
# 5289       1           0
# 5290       0           0
# ...      ...         ...
# 7865       2           0
# 7866       2           1
# 7867       2           0
# 7868       2           0
# 7869       2           1
#
# [2584 rows x 2 columns]

# %%
#accuracy
from sklearn.metrics import accuracy_score
predictions = predictions[predictions["actual"] != 2]
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.5567736883320282

# %%
#home winrate
df.groupby("home").apply(lambda x: x[x["won"] == 1].shape[0]/x.shape[0])
# Out:
# /tmp/ipykernel_1223/3226130610.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby("home").apply(lambda x: x[x["won"] == 1].shape[0]/x.shape[0])
# home
# 0.0    0.440915
# 1.0    0.559085
# dtype: float64

# %%
df_rolling = df[list(selected_columns) + ["won", "team", "season"]]

# %%
df_rolling
# Out:
#        mp        fg       fga       fg%    3p       3pa       3p%        ft  \
# 0     0.0  0.428571  0.508772  0.400000  0.48  0.529412  0.503472  0.568182
# 1     0.0  0.523810  0.543860  0.480488  0.52  0.588235  0.500000  0.204545
# 2     0.0  0.333333  0.350877  0.397561  0.60  0.392157  0.802083  0.295455
# 3     0.0  0.595238  0.719298  0.439024  0.60  0.647059  0.536458  0.318182
# 4     0.0  0.309524  0.403509  0.334146  0.48  0.490196  0.536458  0.272727
# ...   ...       ...       ...       ...   ...       ...       ...       ...
# 7865  0.0  0.476190  0.280702  0.636585  0.48  0.333333  0.718750  0.386364
# 7866  0.0  0.309524  0.350877  0.370732  0.40  0.470588  0.458333  0.204545
# 7867  0.0  0.357143  0.298246  0.468293  0.32  0.352941  0.458333  0.340909
# 7868  0.0  0.380952  0.473684  0.370732  0.36  0.411765  0.458333  0.363636
# 7869  0.0  0.428571  0.280702  0.575610  0.44  0.431373  0.543403  0.250000
#
#            fta       orb  ...  blk%_max_opp  tov%_max_opp  usg%_max_opp  \
# 0     0.576923  0.310345  ...         0.046      0.390608      0.130769
# 1     0.365385  0.172414  ...         0.059      0.386339      1.000000
# 2     0.442308  0.172414  ...         0.098      0.151547      0.528205
# 3     0.346154  0.448276  ...         0.213      1.000000      0.317949
# 4     0.326923  0.379310  ...         0.033      0.359658      0.143590
# ...        ...       ...  ...           ...           ...           ...
# 7865  0.384615  0.275862  ...         0.087      0.227321      0.248718
# 7866  0.192308  0.241379  ...         0.127      0.199573      0.230769
# 7867  0.365385  0.206897  ...         0.048      0.199573      0.061538
# 7868  0.480769  0.517241  ...         0.099      0.134472      0.182051
# 7869  0.269231  0.310345  ...         0.062      0.141942      0.061538
#
#       ortg_max_opp  drtg_max_opp  total_opp  home_opp    won  team  season
# 0         0.540404      0.367089   0.398058       1.0   True   GSW    2022
# 1         0.363636      0.278481   0.466019       0.0  False   LAL    2022
# 2         0.368687      0.341772   0.524272       1.0  False   BRK    2022
# 3         0.383838      0.594937   0.300971       0.0   True   MIL    2022
# 4         0.282828      0.291139   0.359223       0.0  False   PHO    2022
# ...            ...           ...        ...       ...    ...   ...     ...
# 7865      0.646465      0.658228   0.165049       1.0   True   DEN    2024
# 7866      0.494949      0.354430   0.320388       0.0  False   CLE    2024
# 7867      0.595960      0.303797   0.310680       1.0  False   OKC    2024
# 7868      0.237374      0.430380   0.271845       0.0   True   DAL    2024
# 7869      0.661616      0.531646   0.194175       1.0   True   BOS    2024
#
# [7870 rows x 133 columns]

# %%
#last 10 games performance
def find_team_averages(team):
    rolling = team.rolling(10).mean(numeric_only=True)
    return rolling

df_rolling = df_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_averages)
# Out:
# /tmp/ipykernel_1223/1997155124.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_rolling = df_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_averages)

# %%
df_rolling
# Out:
#        mp        fg       fga       fg%     3p       3pa       3p%        ft  \
# 0     NaN       NaN       NaN       NaN    NaN       NaN       NaN       NaN
# 1     NaN       NaN       NaN       NaN    NaN       NaN       NaN       NaN
# 2     NaN       NaN       NaN       NaN    NaN       NaN       NaN       NaN
# 3     NaN       NaN       NaN       NaN    NaN       NaN       NaN       NaN
# 4     NaN       NaN       NaN       NaN    NaN       NaN       NaN       NaN
# ...   ...       ...       ...       ...    ...       ...       ...       ...
# 7865  0.0  0.435714  0.421053  0.468049  0.376  0.419608  0.468403  0.329545
# 7866  0.0  0.333333  0.329825  0.414634  0.304  0.382353  0.407639  0.320455
# 7867  0.0  0.466667  0.410526  0.513171  0.448  0.435294  0.551389  0.345455
# 7868  0.0  0.345238  0.377193  0.396829  0.396  0.456863  0.466319  0.404545
# 7869  0.0  0.445238  0.371930  0.516098  0.496  0.515686  0.529861  0.327273
#
#            fta       orb  ...  ast%_max_opp  stl%_max_opp  blk%_max_opp  \
# 0          NaN       NaN  ...           NaN           NaN           NaN
# 1          NaN       NaN  ...           NaN           NaN           NaN
# 2          NaN       NaN  ...           NaN           NaN           NaN
# 3          NaN       NaN  ...           NaN           NaN           NaN
# 4          NaN       NaN  ...           NaN           NaN           NaN
# ...        ...       ...  ...           ...           ...           ...
# 7865  0.332692  0.368966  ...      0.345082        0.0496        0.0614
# 7866  0.355769  0.268966  ...      0.266862        0.0485        0.0969
# 7867  0.367308  0.296552  ...      0.297892        0.0846        0.0666
# 7868  0.476923  0.420690  ...      0.392857        0.0502        0.0693
# 7869  0.363462  0.341379  ...      0.313115        0.0373        0.0555
#
#       tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  total_opp  \
# 0              NaN           NaN           NaN           NaN        NaN
# 1              NaN           NaN           NaN           NaN        NaN
# 2              NaN           NaN           NaN           NaN        NaN
# 3              NaN           NaN           NaN           NaN        NaN
# 4              NaN           NaN           NaN           NaN        NaN
# ...            ...           ...           ...           ...        ...
# 7865      0.372892      0.155641      0.418182      0.469620   0.326214
# 7866      0.332017      0.165897      0.506061      0.341772   0.283495
# 7867      0.343436      0.130385      0.337374      0.482278   0.222330
# 7868      0.246852      0.174744      0.484343      0.460759   0.325243
# 7869      0.321772      0.154359      0.334343      0.535443   0.249515
#
#       home_opp  season
# 0          NaN     NaN
# 1          NaN     NaN
# 2          NaN     NaN
# 3          NaN     NaN
# 4          NaN     NaN
# ...        ...     ...
# 7865       0.5  2024.0
# 7866       0.5  2024.0
# 7867       0.3  2024.0
# 7868       0.6  2024.0
# 7869       0.3  2024.0
#
# [7870 rows x 131 columns]

# %%
#add rolling cols to df
rolling_cols = [f"{col}_10" for col in df_rolling.columns]
df_rolling.columns = rolling_cols
df = pd.concat([df, df_rolling], axis=1)

# %%
df = df.dropna()

# %%
df
# Out:
#        mp        fg       fga       fg%    3p       3pa       3p%        ft  \
# 246   0.0  0.476190  0.491228  0.463415  0.36  0.450980  0.425347  0.295455
# 249   0.0  0.190476  0.421053  0.182927  0.36  0.627451  0.314236  0.272727
# 252   0.0  0.476190  0.421053  0.517073  0.48  0.588235  0.458333  0.136364
# 257   0.0  0.452381  0.614035  0.358537  0.40  0.294118  0.651042  0.113636
# 259   0.0  0.357143  0.333333  0.441463  0.32  0.352941  0.458333  0.363636
# ...   ...       ...       ...       ...   ...       ...       ...       ...
# 7865  0.0  0.476190  0.280702  0.636585  0.48  0.333333  0.718750  0.386364
# 7866  0.0  0.309524  0.350877  0.370732  0.40  0.470588  0.458333  0.204545
# 7867  0.0  0.357143  0.298246  0.468293  0.32  0.352941  0.458333  0.340909
# 7868  0.0  0.380952  0.473684  0.370732  0.36  0.411765  0.458333  0.363636
# 7869  0.0  0.428571  0.280702  0.575610  0.44  0.431373  0.543403  0.250000
#
#            fta       orb  ...  ast%_max_opp_10  stl%_max_opp_10  \
# 246   0.403846  0.241379  ...         0.381967           0.0738
# 249   0.307692  0.379310  ...         0.381148           0.0643
# 252   0.192308  0.241379  ...         0.296136           0.0642
# 257   0.173077  0.655172  ...         0.283958           0.0447
# 259   0.365385  0.379310  ...         0.314637           0.0792
# ...        ...       ...  ...              ...              ...
# 7865  0.384615  0.275862  ...         0.345082           0.0496
# 7866  0.192308  0.241379  ...         0.266862           0.0485
# 7867  0.365385  0.206897  ...         0.297892           0.0846
# 7868  0.480769  0.517241  ...         0.392857           0.0502
# 7869  0.269231  0.310345  ...         0.313115           0.0373
#
#       blk%_max_opp_10  tov%_max_opp_10  usg%_max_opp_10  ortg_max_opp_10  \
# 246            0.1141         0.430736         0.149103         0.377778
# 249            0.1219         0.445037         0.158718         0.358586
# 252            0.0761         0.402668         0.125897         0.280303
# 257            0.1036         0.424973         0.183462         0.385859
# 259            0.0930         0.534365         0.204872         0.512626
# ...               ...              ...              ...              ...
# 7865           0.0614         0.372892         0.155641         0.418182
# 7866           0.0969         0.332017         0.165897         0.506061
# 7867           0.0666         0.343436         0.130385         0.337374
# 7868           0.0693         0.246852         0.174744         0.484343
# 7869           0.0555         0.321772         0.154359         0.334343
#
#       drtg_max_opp_10  total_opp_10  home_opp_10  season_10
# 246          0.435443      0.431068          0.6     2022.0
# 249          0.334177      0.385437          0.6     2022.0
# 252          0.403797      0.372816          0.5     2022.0
# 257          0.429114      0.266019          0.4     2022.0
# 259          0.391139      0.305825          0.7     2022.0
# ...               ...           ...          ...        ...
# 7865         0.469620      0.326214          0.5     2024.0
# 7866         0.341772      0.283495          0.5     2024.0
# 7867         0.482278      0.222330          0.3     2024.0
# 7868         0.460759      0.325243          0.6     2024.0
# 7869         0.535443      0.249515          0.3     2024.0
#
# [7060 rows x 267 columns]

# %%
#add next game, next date, next opponent info
def shift_col(team, col_name):
    next_col = team[col_name].shift(-1)
    return next_col

def add_col(df, col_name):
    return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))

df["home_next"] = add_col(df, "home")
df["team_opp_next"] = add_col(df, "team_opp")
df["date_next"] = add_col(df, "date")
# Out:
# /tmp/ipykernel_1223/1688004556.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))
# /tmp/ipykernel_1223/1688004556.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["home_next"] = add_col(df, "home")
# /tmp/ipykernel_1223/1688004556.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))
# /tmp/ipykernel_1223/1688004556.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["team_opp_next"] = add_col(df, "team_opp")
# /tmp/ipykernel_1223/1688004556.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))
# /tmp/ipykernel_1223/1688004556.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["date_next"] = add_col(df, "date")

# %%
df
# Out:
#        mp        fg       fga       fg%    3p       3pa       3p%        ft  \
# 246   0.0  0.476190  0.491228  0.463415  0.36  0.450980  0.425347  0.295455
# 249   0.0  0.190476  0.421053  0.182927  0.36  0.627451  0.314236  0.272727
# 252   0.0  0.476190  0.421053  0.517073  0.48  0.588235  0.458333  0.136364
# 257   0.0  0.452381  0.614035  0.358537  0.40  0.294118  0.651042  0.113636
# 259   0.0  0.357143  0.333333  0.441463  0.32  0.352941  0.458333  0.363636
# ...   ...       ...       ...       ...   ...       ...       ...       ...
# 7865  0.0  0.476190  0.280702  0.636585  0.48  0.333333  0.718750  0.386364
# 7866  0.0  0.309524  0.350877  0.370732  0.40  0.470588  0.458333  0.204545
# 7867  0.0  0.357143  0.298246  0.468293  0.32  0.352941  0.458333  0.340909
# 7868  0.0  0.380952  0.473684  0.370732  0.36  0.411765  0.458333  0.363636
# 7869  0.0  0.428571  0.280702  0.575610  0.44  0.431373  0.543403  0.250000
#
#            fta       orb  ...  tov%_max_opp_10  usg%_max_opp_10  \
# 246   0.403846  0.241379  ...         0.430736         0.149103
# 249   0.307692  0.379310  ...         0.445037         0.158718
# 252   0.192308  0.241379  ...         0.402668         0.125897
# 257   0.173077  0.655172  ...         0.424973         0.183462
# 259   0.365385  0.379310  ...         0.534365         0.204872
# ...        ...       ...  ...              ...              ...
# 7865  0.384615  0.275862  ...         0.372892         0.155641
# 7866  0.192308  0.241379  ...         0.332017         0.165897
# 7867  0.365385  0.206897  ...         0.343436         0.130385
# 7868  0.480769  0.517241  ...         0.246852         0.174744
# 7869  0.269231  0.310345  ...         0.321772         0.154359
#
#       ortg_max_opp_10  drtg_max_opp_10  total_opp_10  home_opp_10  season_10  \
# 246          0.377778         0.435443      0.431068          0.6     2022.0
# 249          0.358586         0.334177      0.385437          0.6     2022.0
# 252          0.280303         0.403797      0.372816          0.5     2022.0
# 257          0.385859         0.429114      0.266019          0.4     2022.0
# 259          0.512626         0.391139      0.305825          0.7     2022.0
# ...               ...              ...           ...          ...        ...
# 7865         0.418182         0.469620      0.326214          0.5     2024.0
# 7866         0.506061         0.341772      0.283495          0.5     2024.0
# 7867         0.337374         0.482278      0.222330          0.3     2024.0
# 7868         0.484343         0.460759      0.325243          0.6     2024.0
# 7869         0.334343         0.535443      0.249515          0.3     2024.0
#
#       home_next  team_opp_next   date_next
# 246         0.0            LAC  2021-11-07
# 249         0.0            DAL  2021-11-08
# 252         0.0            SAC  2021-11-07
# 257         1.0            BRK  2021-11-07
# 259         0.0            NYK  2021-11-07
# ...         ...            ...         ...
# 7865        NaN           None        None
# 7866        NaN           None        None
# 7867        NaN           None        None
# 7868        NaN           None        None
# 7869        NaN           None        None
#
# [7060 rows x 270 columns]

# %%
df = df.copy()

# %%
#opponents last 10 games
full = df.merge(df[rolling_cols + ["team_opp_next", "date_next", "team"]], 
    left_on=["team", "date_next"],
    right_on=["team_opp_next", "date_next"]
)

# %%
full
# Out:
#        mp        fg       fga       fg%    3p       3pa       3p%        ft  \
# 0     0.0  0.190476  0.456140  0.163415  0.28  0.392157  0.368056  0.431818
# 1     0.0  0.476190  0.298246  0.619512  0.44  0.274510  0.748264  0.340909
# 2     0.0  0.452381  0.385965  0.514634  0.28  0.372549  0.383681  0.250000
# 3     0.0  0.428571  0.298246  0.558537  0.36  0.294118  0.586806  0.181818
# 4     0.0  0.428571  0.631579  0.324390  0.16  0.352941  0.227431  0.136364
# ...   ...       ...       ...       ...   ...       ...       ...       ...
# 6991  0.0  0.595238  0.508772  0.582927  0.52  0.431373  0.645833  0.227273
# 6992  0.0  0.452381  0.438596  0.475610  0.32  0.352941  0.458333  0.363636
# 6993  0.0  0.452381  0.456140  0.463415  0.64  0.490196  0.723958  0.386364
# 6994  0.0  0.238095  0.280702  0.331707  0.24  0.450980  0.277778  0.454545
# 6995  0.0  0.571429  0.385965  0.658537  0.44  0.313725  0.685764  0.250000
#
#            fta       orb  ...  blk%_max_opp_10_y  tov%_max_opp_10_y  \
# 0     0.461538  0.379310  ...             0.1128           0.443543
# 1     0.365385  0.206897  ...             0.1122           0.247492
# 2     0.307692  0.275862  ...             0.0898           0.412593
# 3     0.250000  0.137931  ...             0.1075           0.546852
# 4     0.173077  0.379310  ...             0.0967           0.333084
# ...        ...       ...  ...                ...                ...
# 6991  0.326923  0.482759  ...             0.1394           0.261046
# 6992  0.326923  0.275862  ...             0.0694           0.243970
# 6993  0.461538  0.413793  ...             0.0711           0.423479
# 6994  0.461538  0.206897  ...             0.0949           0.334792
# 6995  0.307692  0.241379  ...             0.0561           0.327001
#
#       usg%_max_opp_10_y  ortg_max_opp_10_y  drtg_max_opp_10_y  total_opp_10_y  \
# 0              0.155769           0.422222           0.426582        0.429126
# 1              0.141282           0.499495           0.465823        0.366019
# 2              0.185769           0.424747           0.455696        0.283495
# 3              0.205641           0.518182           0.408861        0.283495
# 4              0.176667           0.370707           0.403797        0.340777
# ...                 ...                ...                ...             ...
# 6991           0.180897           0.355051           0.551899        0.371845
# 6992           0.171282           0.520202           0.431646        0.331068
# 6993           0.133974           0.287374           0.494937        0.222330
# 6994           0.152436           0.529798           0.354430        0.297087
# 6995           0.168333           0.307071           0.529114        0.273786
#
#       home_opp_10_y  season_10_y  team_opp_next_y  team_y
# 0               0.7       2022.0              LAL     CHO
# 1               0.5       2022.0              PHI     NYK
# 2               0.4       2022.0              BOS     TOR
# 3               0.7       2022.0              WAS     CLE
# 4               0.4       2022.0              SAS     SAC
# ...             ...          ...              ...     ...
# 6991            0.3       2024.0              IND     NYK
# 6992            0.6       2024.0              OKC     DAL
# 6993            0.2       2024.0              DAL     OKC
# 6994            0.5       2024.0              BOS     CLE
# 6995            0.2       2024.0              CLE     BOS
#
# [6996 rows x 403 columns]

# %%
full[["team_x", "team_opp_next_x", "team_y", "team_opp_next_y", "date_next"]]
# Out:
#      team_x team_opp_next_x team_y team_opp_next_y   date_next
# 0       LAL             CHO    CHO             LAL  2021-11-08
# 1       PHI             NYK    NYK             PHI  2021-11-08
# 2       BOS             TOR    TOR             BOS  2021-11-10
# 3       WAS             CLE    CLE             WAS  2021-11-10
# 4       SAS             SAC    SAC             SAS  2021-11-10
# ...     ...             ...    ...             ...         ...
# 6991    IND             NYK    NYK             IND  2024-05-10
# 6992    OKC             DAL    DAL             OKC  2024-05-11
# 6993    DAL             OKC    OKC             DAL  2024-05-11
# 6994    BOS             CLE    CLE             BOS  2024-05-11
# 6995    CLE             BOS    BOS             CLE  2024-05-11
#
# [6996 rows x 5 columns]

# %%
removed_columns = list(full.columns[full.dtypes == "object"]) + removed_columns

# %%
removed_columns
# Out:
# ['team_x',
#  'team_opp',
#  'date',
#  'team_opp_next_x',
#  'date_next',
#  'team_opp_next_y',
#  'team_y',
#  'season',
#  'date',
#  'won',
#  'target',
#  'team',
#  'team_opp']

# %%
selected_columns = full.columns[~full.columns.isin(removed_columns)]

# %%
sfs.fit(full[selected_columns], full["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30, n_jobs=1)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['fga',
#  'ft',
#  'usg%',
#  '3p_opp',
#  'usg%_opp',
#  'stl_max_opp',
#  'tov_max_opp',
#  'fg%_10_x',
#  'efg%_10_x',
#  'usg%_10_x',
#  'drtg_10_x',
#  'pts_max_10_x',
#  'usg%_opp_10_x',
#  'trb_max_opp_10_x',
#  'blk_max_opp_10_x',
#  'blk%_max_opp_10_x',
#  'drtg_max_opp_10_x',
#  'home_next',
#  '3p%_10_y',
#  'pf_10_y',
#  'usg%_10_y',
#  'fg_max_10_y',
#  'trb_max_10_y',
#  'pts_opp_10_y',
#  'ts%_opp_10_y',
#  'usg%_opp_10_y',
#  'fta_max_opp_10_y',
#  'trb_max_opp_10_y',
#  'drtg_max_opp_10_y',
#  'total_opp_10_y']

# %%
predictions = backtest(full, rr, predictors)

# %%
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.6535260621988611
